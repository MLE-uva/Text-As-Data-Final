# %% [markdown]
# # Final Project Notebook
#
# DS 5001 Text as Data

# %% [markdown]
# # Metadata
#
# - Full Name:Mason Earp
# - Userid:atx6qu
# - GitHub Repo URL:https://github.com/MLE-uva/Text-As-Data-Final
# - UVA Box URL:

# %% [markdown]
# # Overview
#
# The goal of the final project is for you to create a **digital analytical edition** of a corpus using the tools, practices, and perspectives you’ve learning in this course. You will select a corpus that has already been digitized and transcribed, parse that into an F-compliant set of tables, and then generate and visualize the results of a series of fitted models. You will also draw some tentative conclusions regarding the linguistic, cultural, psychological, or historical features represented by your corpus. The point of the exercise is to have you work with a corpus through the entire pipeline from ingestion to interpretation.
#
# Specifically, you will acquire a collection of long-form texts and perform the following operations:
#
# - **Convert** the collection from their source formats (F0) into a set of tables that conform to the Standard Text Analytic Data Model (F2).
# - **Annotate** these tables with statistical and linguistic features using NLP libraries such as NLTK (F3).
# - **Produce** a vector representation of the corpus to generate TFIDF values to add to the TOKEN (aka CORPUS) and VOCAB tables (F4).
# - **Model** the annotated and vectorized model with tables and features derived from the application of unsupervised methods, including PCA, LDA, and word2vec (F5).
# - **Explore** your results using statistical and visual methods.
# - **Present** conclusions about patterns observed in the corpus by means of these operations.
#
# When you are finished, you will make the results of your work available in GitHub (for code) and UVA Box (for data). You will submit to Gradescope (via Canvas) a PDF version of a Jupyter notebook that contains the information listed below.
#
# # Some Details
#
# - Please fill out your answers in each task below by editing the markdown cell.
# - Replace text that asks you to insert something with the thing, i.e. replace `(INSERT IMAGE HERE)` with an image element, e.g. `![](image.png)`.
# - For URLs, just paste the raw URL directly into the text area. Don't worry about providing link labels using `[label](link)`.
# - Please do not alter the structure of the document or cell, i.e. the bulleted lists.
# - You may add explanatory paragraphs below the bulleted lists.
# - Please name your tables as they are named in each task below.
# - Tasks are indicated by headers with point values in parentheses.

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Source Description (1)

# %% [markdown]
# Provide a brief description of your source material, including its provenance and content. Tell us where you found it and what kind of content it contains.
#
# The source material for this analysis consists of the fantasy novels of Brandon Sanderson, specifically the novels that are set in the "Cosmere", the fictional universe where the majority of his works take place. The content consists of the full narrative texts for textual analysis. I have purchased the majority of Brandon Sanderson's works as physical novels but needed to facilitate with the digital repository at Anna's Archive(https://annas-archive.gl/).

# %% [markdown]
# ## Source Features (1)
#
# Add values for the following items. (Do this for all following bulleted lists.)
#
# - Source URL: https://annas-archive.gl/
# - UVA Box URL:
# - Number of raw documents: 26
# - Total size of raw documents (e.g. in MB): 335 MB
# - File format(s), e.g. XML, plaintext, etc.: .epub, ePub, ePUB, or EPUB

# %% [markdown]
# ## Source Document Structure (1)
#
# Provide a brief description of the internal structure of each document. That, describe the typical elements found in document and their relation to each other. For example, a corpus of letters might be described as having a date, an addressee, a salutation, a set of content paragraphs, and closing. If they are various structures, state that.
#
# Each of the documents are novels by Brandon Sanderson and will follow a similar format with Chapters, paragprahs, and sentences. Most of these novels will have a prologue and an epilogue that ground the story in the broader context of the author's universe the "Cosmere".

# %% [markdown]
# # Parsed and Annotated Data
#
# Parse the raw data into the three core tables of your addition: the `LIB`, `CORPUS`, and `VOCAB` tables.
#
# These tables will be stored as CSV files with header rows.
#
# You may consider using `|` as a delimitter.
#
# Provide the following information for each.

# %% [markdown]
# ## LIB (2)
#
# The source documents the corpus comprises. These may be books, plays, newspaper articles, abstracts, blog posts, etc.
#
# Note that these are *not* documents in the sense used to describe a bag-of-words representation of a text, e.g. chapter.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:
# - Number of observations:
# - List of features, including at least three that may be used for model summarization (e.g. date, author, etc.):
# - Average length of each document in characters:

# %% [markdown]
# ## CORPUS (2)
#
# The sequence of word tokens in the corpus, indexed by their location in the corpus and document structures.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Number of observations Between (should be >= 500,000 and <= 2,000,000 observations.): 2224830
# - OHCO Structure (as delimitted column names): OHCO = ['title', 'chapter_id', 'paragraph_id', 'sent_id', 'token_id']
# - Columns (as delimitted column names, including `token_str`, `term_str`, `pos`, and `pos_group`): Columns = 'title', 'chapter_id', 'paragraph_id', 'sent_id', 'token_id', 'token_str', 'term_str', 'pos', 'pos_group'

# %% [markdown]
# ## VOCAB (2)
#
# The unique word types (terms) in the corpus.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Number of observations:58423
# - Columns (as delimitted names, including `n`, `p`', `i`, `dfidf`, `porter_stem`, `max_pos` and `max_pos_group`, `stop`): Columns = 'n', 'p', 'i', 'dfidf', 'porter_stem', 'max_pos', 'max_pos_group', 'stop'
# - Note: Your VOCAB may contain ngrams. If so, add a feature for `ngram_length`.
# - List the top 20 significant words in the corpus by DFIDF.
# Top 20 words:
#  'link',
#  'education',
#  'passes',
#  'whimpered',
#  'cruel',
#  'witness',
#  'stoic',
#  'sputtered',
#  'seeped',
#  'maid',
#  'decisive',
#  'assign',
#  'absolute',
#  'frost',
#  'throbbed',
#  'survivor',
#  'rebel',
#  'worms',
#  'patched',
#  'narrowly'

# %% [markdown]
# # Derived Tables

# %% [markdown]
# ## BOW (3)
#
# A bag-of-words representation of the CORPUS.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Bag (expressed in terms of OHCO levels): I chose to construct the BOW at the chapter level. OHCO[:2] = [`title`, `chapter_id`]
# - Number of observations: 638071
# - Columns (as delimitted names, including `n`, `tfidf`): I have the index set to: [`title`, `chapter_id`, `term_str`] and the columns:[`n`, `tf`, `idf`, `tfidf`]

# %% [markdown]
# ## DTM (3)
#
# A represenation of the BOW as a sparse count matrix.
#
# - UVA Box URL:
# - UVA Box URL of BOW used to generate (if applicable):
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Bag (expressed in terms of OHCO levels): I chose to set the bag at the chapter level. OHCO[:2] = [`title`, `chapter_id`]

# %% [markdown]
# ## TFIDF (3)
#
# A Document-Term matrix with TFIDF values.
#
# - UVA Box URL:
# - UVA Box URL of DTM or BOW used to create:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Description of TFIDIF formula ($\LaTeX$ OK):$$tfidf(t, d, D) = tf(t, d) \times idf(t, D)$$

# %% [markdown]
# ## Reduced and Normalized TFIDF_L2 (3)

# %% [markdown]
# A Document-Term matrix with L2 normalized TFIDF values.
#
# - UVA Box URL:
# - UVA Box URL of source TFIDF table:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Number of features (i.e. significant words):12935
# - Principle of significant word selection: The priciple that I used to develop the reduced `TFIDF_L2` is document entropy. I only used the top 20% of words with high `dh`. `dh` = `dp` * `di`. Document entropy is equal to probability multipled by information for each term in a document. This helps to fidn the balance of words with high meaning without only selecting high probaility words like stop words.

# %% [markdown]
# # Models

# %% [markdown]
# ## PCA Components (4)
#
# - UVA Box URL:
# - UVA Box URL of the source TFIDF_L2 table:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Number of components: 10
# - Library used to generate:SciKit Learn's PCA package
# - Top 5 positive terms for first component: kiss, planet, protocols, restaurant, nope
# - Top 5 negative terms for second component: wax, prof, wayne, marasi, megan

# %% [markdown]
# ## PCA DCM (4)
#
# The document-component matrix generated.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## PCA Loadings (4)
#
# The component-term matrix generated.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## PCA Visualization 1 (4)
#
# Include a scatterplot of documents in the space created by the first two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![PCA_Documnet_Scatterplot.png](attachment:PCA_Documnet_Scatterplot.png)
#
# ![PCA_Loadings_Scatterplot.png](attachment:PCA_Loadings_Scatterplot.png)
#
# Briefly describe the nature of the polarity you see in the first component:
#
# In the first Component: Component 0 we are seeing the differences in Things(kiss planet protocols restaurant nope stack) vs Characters(kaladin shallan dalinar adolin syl wax).

# %% [markdown]
# ## PCA Visualization 2 (4)
#
# Include a scatterplot of documents in the space created by the second two components.
#
# Color the points based on a metadata feature associated with the documents.
#
# Also include a scatterplot of the loadings for the same two components. (This does not need a feature mapped onto color.)
#
# ![PCA_Documnet_Scatterplot_PC2_PC3.png](attachment:PCA_Documnet_Scatterplot_PC2_PC3.png)
#
# ![PCA_Loadings_Scatterplot_PC2_PC3.png](attachment:PCA_Loadings_Scatterplot_PC2_PC3.png)
#
# Briefly describe the nature of the polarity you see in the second component:
#
# In the second of the two components PC2, PC3. In PC3 we see a clear division in Characters from different trilogies in the Mistborn Novels. The positive half are from the second trilogy =(wax wayne marasi waxillium kaladin) and the negative are from the first trilogy= (raeth vin elend kelsier sazed)

# %% [markdown]
# ## LDA TOPIC (4)
#
# - UVA Box URL:
# - UVA Box URL of count matrix used to create:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Libary used to compute: Sci-Kit Learn's LatentDirichletAllocation
# - A description of any filtering, e.g. POS (Nouns and Verbs only): All noun's except for proper nouns, all verbs, all adjectives, and all adverbs.
# - Number of components:15
# - Any other parameters used:removed stop words, included bi-grams, n_topics = 15, max_iter = 100, and n_top_terms = 10.
# - Top 5 words and best-guess labels for topic five topics by mean document weight:
#   - T00:gun tunnel steel mobile hole (Seedy alley)
#   - T01:gun ship train governor bubble (Training on a Boat)
#   - T02:cloak village inn gleeman al (Traditional Fantasy)
#   - T03:ship, spores, captain, tress, deck (Being on a Boat)
#   - T04:camp gateway tent bloody weave (Camping)
#
# - By Mean Document weight:
#   - T01:gun ship train governor bubble (Training on a Boat)
#   - T12:priests servants palace children god (Religion)
#   - T09:skaa mists street soldier rope (The Streets)
#   - T02:cloak village inn gleeman al (Traditional Fantasy)
#   - T10:lord creatures sule lord said (Heavenly Creatures)

# %% [markdown]
# ## LDA THETA (4)
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:comma

# %% [markdown]
# ## LDA PHI (4)
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:comma

# %% [markdown]
# ## LDA + PCA Visualization (4)
#
# Apply PCA to the THETA table and plot the topics in the space opened by the first two components.
#
# Size the points based on the mean document weight of each topic (using the THETA table).
#
# Color the points basd on a metadata feature from the LIB table.
#
# Provide a brief interpretation of what you see.
#
# ![LDAwithPCA.png](attachment:LDAwithPCA.png)
#
# These topic ranked by PCA over Mean Weight show a clear authorship divide between the 2 Author Brandon Sanderson and Robert Jordan. The first principle componenet is dominated by T01 which is exclusicely Brandon Sanderson. The second priniple component is dominated T02 by Robert Jordan. The neat thing is that on project they both worked on we see a clustering around both principle components.

# %% [markdown]
# ## Sentiment VOCAB_SENT (4)
#
# Sentiment values associated with a subset of the VOCAB from a curated sentiment lexicon.
#
# - UVA Box URL:
# - UVA Box URL for source lexicon:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## Sentiment BOW_SENT (4)
#
# Sentiment values from VOCAB_SENT mapped onto BOW.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:

# %% [markdown]
# ## Sentiment DOC_SENT (4)
#
# Computed sentiment per bag computed from BOW_SENT.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter: comma
# - Document bag expressed in terms of OHCO levels: OHCO = ['title', 'chapter_id']

# %% [markdown]
# ## Sentiment Plot (4)
#
# Plot sentiment over some metric space, such as time.
#
# If you don't have a metric metadata features, plot sentiment over a feature of your choice.
#
# You may use a bar chart or a line graph.
#
# ![SentimentOverTime.png](attachment:SentimentOverTime.png)

# %% [markdown]
# ## VOCAB_W2V (4)
#
# A table of word2vec features associated with terms in the VOCAB table.
#
# - UVA Box URL:
# - GitHub URL for notebook used to create:
# - Delimitter:
# - Document bag expressed in terms of OHCO levels: OHCO = ['title', 'chapter_id', 'paragraph_id', 'sent_id']
# - Number of features generated:200 is the the vector_size to 200.
# - The library used to generate the embeddings: Gensim

# %% [markdown]
# ## Word2vec tSNE Plot (4)
#
# Plot word embedding featues in two-dimensions using t-SNE.
#
# Describe a cluster in the plot that captures your attention.
#
# ![Zoomed_in_TSNE_plot.png](attachment:Zoomed_in_TSNE_plot.png)
#
# This zoomed in section of the tSNE Plot is the numbers section it covers distances, numbers, and timeframes (minutes, hours, days, weeks, etc.)

# %% [markdown]
# # Riffs
#
# Provde at least three visualizations that combine the preceding model data in interesting ways.
#
# These should provide insight into how features in the LIB table are related.
#
# The nature of this relationship is left open to you -- it may be correlation, or mutual information, or something less well defined.
#
# In doing so, consider the following visualization types:
#
# - Hierarchical cluster diagrams
# - Heatmaps
# - Scatter plots
# - KDE plots
# - Dispersion plots
# - t-SNE plots
# - etc.

# %% [markdown]
# ## Riff 1 (5)
#
# ![Dendrogram.png](attachment:Dendrogram.png)
#
# Hierarchical Cluster Diagram - This shows the different series as their own cluster Mistborn, The Stormlight Archive, The Wheel of Time, and The Satndalone Novels. This was generated using Cosine Similarity with Ward as the linkage method.

# %% [markdown]
# ## Riff 2 (5)
#
# ![Syuzhet_Series_Plot.png](attachment:Syuzhet_Series_Plot.png)
#
# I am showing the syuzhet sentiment across the 3 different series:Mistborn, The Stormlight Archive, The Wheel of Time. We see that 'The Way of Kings' in The Stormlight Archive series has a really significant negative sentiment halfway through the book. Which is interesting as this is the the first book in the series, I guess things have to get bad before they can get better. The same thing is seen in the Wheel of Time Series, 'A Memory of Light' has a signifiacnt drop in sentiment roughly 80 percent through the book.

# %% [markdown]
# ## Riff 3 (5)
#
# ![topic-graph.png](attachment:topic-graph.png)
#
# I created a Topic Web Graph to see the distances in Topic Groups. It is interesting to see the that CrossAuthor works are is most closely related to wilderness/traveling while the rest of the topics form their own cluster.

# %% [markdown]
# # Interpretation (4)
#
# Describe something interesting about your corpus that you discovered during the process of completing this assignment.
#
# At a minumum, use 250 words, but you may use more. You may also add images if you'd like.
#
# This was a very rewarding project. I realized that while the ePub file format sounds like it would be easy to transform into a corpus, it was actually quite difficult due to how different publishers use various parsing structures to denote chapters versus paragraphs.
#
# I was surprised to see that, through various methods, the models were able to differentiate between Brandon Sanderson and Robert Jordan. This is noteworthy because Sanderson was selected to finish 'The Wheel of Time' series by Robert Jordan's wife after his passing in 2007. I would have expected their writing styles to be similar enough that a clear distinction could not be made.
#
# One of the major successes of this project was the "First Riff." By using TF-IDF, I was able to generate a hierarchical cluster in the form of a dendrogram. It accurately clustered the novels into their respective series: Mistborn, The Wheel of Time, The Stormlight Archive, and standalone novels. I will admit that I had to find the right similarity function (Cosine) and linkage method (Ward) to make it work effectively.
#
# I struggled initially with forming topics for the Brandon Sanderson corpus. One frustrating aspect of using Scikit-Learn's Latent Dirichlet Allocation (LDA) was that every time I reran the notebook, it would recalculate the topics, leading to different results from run to run. Once I filtered out stopwords and proper nouns, however, the topics began to take on more significant meaning.
#
# As I haven't yet read the latest book in 'The Stormlight Archive', I wanted to see if I could glean any insights beforehand that weren't necessarily spoilers. This led to the "Second Riff," where I mapped the syuzhet sentiment of each series over narrative time. It looks like I'm in for a emotional rollercoaster; the book starts with fairly negative sentiment before reaching a peak in the first third, falling to its lowest point in the second third, and finally rising again to end on a positive sentiment score.
